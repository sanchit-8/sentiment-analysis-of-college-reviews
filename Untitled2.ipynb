# %%
list1=[]
fhandle=open('iot', encoding="utf8")
count=0
for var in fhandle:
    #print(var)
    index=var.find('zxy')
    index2=var.find('|')
    #print(index)
    list1.insert(0,var[index+4:index2-13])
leng=len(list1)
for i in range(0,leng):
    str=list1[i]

# %%
list1.remove(list1[14])
list1.remove(list1[21])

# %%
list1
# Out:
# ['University Institute Of Chemical Engineering And Technology',
#  'Noida Institute Of Engineering & Technology',
#  'Anand Institute Of Higher Technology',
#  'Government College Of Engineering, Aurangabad (Academic Autonomous)',
#  'The National Institute Of Engineering',
#  'Maharashtra Academy Of Engineering And Educational Research, Mit College Of Engineering, Pune-Pune',
#  'Adhiyamaan College Of Engineering (Engineering & Technology)',
#  'Yeshwantrao Chavan College Of Engineering-Nagpur',
#  'National Institute Of Technology, Delhi',
#  'Bengal Institute Of Technology',
#  'Sri Ramakrishna Engineering College-Coimbatore',
#  'Shri Guru Gobind Singhji Institute Of Engineering And Technology-Nanded',
#  "Vignan's Foundation For Science, Technology And Research",
#  'National Institute Of Technology, Patna',
#  'K. K. Wagh Institute Of Engineering Education & Research-Nashik',
#  'Veermata Jijabai Technological Institute',
#  'College Of Technology And Engineering-Udaipur',
# ...

# %%
import import_ipynb
import evaluation as ft
# Out:
# importing Jupyter notebook from evaluation.ipynb
# hello

# %%
import segregation as sg
# Out:
# importing Jupyter notebook from segregation.ipynb
# /home/sanchit/.local/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/sanchit/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /home/sanchit/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# /home/sanchit/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...

# %%
for i in list1:
    a=i+" college reviews"
    print(a)
    print("start")
    sg.segregate(a)
    x=ft.evaluate(a)
    print (x)
# Out:
# University Institute Of Chemical Engineering And Technology college reviews
# start
# ...
